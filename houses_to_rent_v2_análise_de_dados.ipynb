# %% [markdown]
# <a href="https://colab.research.google.com/github/IgorB99/FATEC-MECATRONICA-0791811036-Igor/blob/master/houses_to_rent_v2_an%C3%A1lise_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/houses_to_rent_v2.csv")

# %%
data.head()
# Out:
#            city  area  ...  fire insurance (R$)  total (R$)
# 0     São Paulo    70  ...                   42        5618
# 1     São Paulo   320  ...                   63        7973
# 2  Porto Alegre    80  ...                   41        3841
# 3  Porto Alegre    51  ...                   17        1421
# 4     São Paulo    25  ...                   11         836
#
# [5 rows x 13 columns]

# %%
data.dtypes
# Out:
# city                   object
# area                    int64
# rooms                   int64
# bathroom                int64
# parking spaces          int64
# floor                  object
# animal                 object
# furniture              object
# hoa (R$)                int64
# rent amount (R$)        int64
# property tax (R$)       int64
# fire insurance (R$)     int64
# total (R$)              int64
# dtype: object

# %%
data.columns
# Out:
# Index(['city', 'area', 'rooms', 'bathroom', 'parking spaces', 'floor',
#        'animal', 'furniture', 'hoa (R$)', 'rent amount (R$)',
#        'property tax (R$)', 'fire insurance (R$)', 'total (R$)'],
#       dtype='object')

# %%
datacity = data.groupby('city')

# %%
datacity.describe()
# Out:
#                   area                           ... total (R$)
#                  count        mean          std  ...        50%      75%        max
# city                                             ...
# Belo Horizonte  1258.0  207.411765  1312.428950  ...     3040.0  5925.75  1120000.0
# Campinas         853.0  137.561547   448.843132  ...     2140.0  3632.00    20560.0
# Porto Alegre    1193.0  103.609388   101.522925  ...     2211.0  3338.00    32750.0
# Rio de Janeiro  1501.0  105.347768    93.485031  ...     3253.0  5566.00    95610.0
# São Paulo       5887.0  158.899439   347.474169  ...     4596.0  8591.00   316900.0
#
# [5 rows x 72 columns]

# %%
data.plot(figsize=(12,8)).scatter(x='city', y='datacity')

# %% [markdown]
# ###PREÇO

# %%
data_preço = data[data['total (R$)']>100000]

# %%
data_preço
# Out:
#                 city  area  ...  fire insurance (R$)  total (R$)
# 255   Belo Horizonte   155  ...                   38     1120000
# 2859       São Paulo   285  ...                  254      222100
# 6230       São Paulo   340  ...                  153      233200
# 6645       São Paulo    42  ...                   32      316900
# 6979  Belo Horizonte   155  ...                   38     1120000
#
# [5 rows x 13 columns]

# %%
data_preço.boxplot(column=['total (R$)'], showmeans=True)

# %%
data_preço.describe()
# Out:
#            area     rooms  ...  fire insurance (R$)    total (R$)
# count    5.0000  5.000000  ...             5.000000  5.000000e+00
# mean   195.4000  2.400000  ...           103.000000  6.024400e+05
# std    118.0394  1.949359  ...            98.478424  4.738846e+05
# min     42.0000  1.000000  ...            32.000000  2.221000e+05
# 25%    155.0000  1.000000  ...            38.000000  2.332000e+05
# 50%    155.0000  1.000000  ...            38.000000  3.169000e+05
# 75%    285.0000  4.000000  ...           153.000000  1.120000e+06
# max    340.0000  5.000000  ...           254.000000  1.120000e+06
#
# [8 rows x 9 columns]

# %% [markdown]
# ###AREA

# %%
dados_filtrados = data[data['area'] > 12000]

# %%
dados_filtrados
# Out:
#                 city   area  ...  fire insurance (R$)  total (R$)
# 2397  Belo Horizonte  46335  ...                  114       10220
# 5915       São Paulo  24606  ...                  103       18320
# 9241        Campinas  12732  ...                   21        2417
#
# [3 rows x 13 columns]

# %%
dados_filtrados_area_min = data[data['area'] < 150]

# %%
dados_filtrados_area_min.boxplot(column=['area'], showmeans=True)

# %% [markdown]
# ###POR CIDADE

# %%
dados_filtrados_SP = data[data['city'] == 'São Paulo']

# %%
dados_filtrados_SP.describe()
# Out:
#                area        rooms  ...  fire insurance (R$)     total (R$)
# count   5887.000000  5887.000000  ...          5887.000000    5887.000000
# mean     158.899439     2.558859  ...            62.428911    6380.831833
# std      347.474169     1.166365  ...            50.073429    7541.320897
# min       11.000000     1.000000  ...             4.000000     508.000000
# 25%       59.000000     2.000000  ...            26.000000    2631.000000
# 50%      106.000000     3.000000  ...            45.000000    4596.000000
# 75%      212.000000     3.000000  ...            83.000000    8591.000000
# max    24606.000000    10.000000  ...           677.000000  316900.000000
#
# [8 rows x 9 columns]

# %%
dados_filtrados_BH = data[data['city'] == 'Belo Horizonte']

# %%
dados_filtrados_BH.describe()
# Out:
#                area        rooms  ...  fire insurance (R$)    total (R$)
# count   1258.000000  1258.000000  ...          1258.000000  1.258000e+03
# mean     207.411765     3.020668  ...            53.675676  6.315242e+03
# std     1312.428950     1.277510  ...            53.625693  4.465483e+04
# min       15.000000     1.000000  ...             6.000000  4.990000e+02
# 25%       67.250000     2.000000  ...            17.000000  1.611250e+03
# 50%      110.000000     3.000000  ...            32.000000  3.040000e+03
# 75%      220.000000     4.000000  ...            67.000000  5.925750e+03
# max    46335.000000    10.000000  ...           246.000000  1.120000e+06
#
# [8 rows x 9 columns]

# %%
dados_filtrados_CP = data[data['city'] == 'Campinas']

# %%
dados_filtrados_CP.describe()
# Out:
#                area       rooms  ...  fire insurance (R$)    total (R$)
# count    853.000000  853.000000  ...           853.000000    853.000000
# mean     137.561547    2.355217  ...            32.388042   3173.276671
# std      448.843132    1.075424  ...            33.179137   2857.281849
# min       20.000000    1.000000  ...             3.000000    711.000000
# 25%       55.000000    1.000000  ...            13.000000   1417.000000
# 50%       75.000000    2.000000  ...            20.000000   2140.000000
# 75%      137.000000    3.000000  ...            38.000000   3632.000000
# max    12732.000000    7.000000  ...           226.000000  20560.000000
#
# [8 rows x 9 columns]

# %%
dados_filtrados_PA = data[data['city'] == 'Porto Alegre']

# %%
dados_filtrados_PA.describe()
# Out:
#               area        rooms  ...  fire insurance (R$)    total (R$)
# count  1193.000000  1193.000000  ...          1193.000000   1193.000000
# mean    103.609388     2.140821  ...            36.425817   2989.782900
# std     101.522925     1.058816  ...            36.564961   2734.499521
# min      18.000000     1.000000  ...             8.000000    509.000000
# 25%      48.000000     1.000000  ...            17.000000   1465.000000
# 50%      70.000000     2.000000  ...            25.000000   2211.000000
# 75%     109.000000     3.000000  ...            40.000000   3338.000000
# max     981.000000     8.000000  ...           338.000000  32750.000000
#
# [8 rows x 9 columns]

# %%
dados_filtrados_RJ = data[data['city'] == 'Rio de Janeiro']

# %%
dados_filtrados_RJ.describe()
# Out:
#               area        rooms  ...  fire insurance (R$)    total (R$)
# count  1501.000000  1501.000000  ...          1501.000000   1501.000000
# mean    105.347768     2.243837  ...            42.483011   4611.684877
# std      93.485031     1.050319  ...            37.512476   4425.357934
# min      15.000000     1.000000  ...             6.000000    507.000000
# 25%      53.000000     1.000000  ...            19.000000   2067.000000
# 50%      80.000000     2.000000  ...            30.000000   3253.000000
# 75%     120.000000     3.000000  ...            51.000000   5566.000000
# max     950.000000    13.000000  ...           229.000000  95610.000000
#
# [8 rows x 9 columns]
